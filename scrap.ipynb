# %%
import requests
from bs4 import BeautifulSoup

# %%
base_url = "https://www.flipkart.com/search?q="
search_string = "realmegtneo3t"

# %%
search_url = base_url + search_string

# %%
search_url
# Out:
# 'https://www.flipkart.com/search?q=realmegtneo3t'

# %%
r = requests.get(search_url)

# %%
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("div",{"class":"cPHDOP col-12-12"})
# Out:
# [<div class="cPHDOP col-12-12"><div class="_0BvurA"><section class="pgRLLn _2OLUF3"><div class="_3Owiq+"><div class="rgHxCQ"><span>Filters</span></div></div></section><div class="GSeM5C"><section class="Iu4qXa"><div class="WCyB2K"><span>CATEGORIES</span></div><div><div class="esFpML"><span><svg class="IZmjtf" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="P3pAQJ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="k17cBJ WyLc0s" href="/mobiles-accessories/pr?sid=tyy&amp;q=realmegtneo3t&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="esFpML"><span><svg class="IZmjtf" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="hEjLuS WyLc0s" href="/mobiles/pr?sid=tyy,4io&am
# ...

# %%
# soup.find_all("div",{"class":"cPHDOP col-12-12"})[2:-4] this was for iphone 11

# %%
# bigbox = soup.find_all("div",{"class":"cPHDOP col-12-12"})[2:-4] this was for iphone 11

# %%
bigbox = soup.find_all("div",{"class":"cPHDOP col-12-12"})
del bigbox[0:3]

# %%
len(bigbox)
# Out:
# 11

# %%
bigbox[0]
# Out:
# <div class="cPHDOP col-12-12"><div class="_75nlfW"><div data-id="MOBGHBJG8XXGVZ6S" style="width:100%"><div class="tUxRFH"><a class="CGtC98" href="/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&amp;lid=LSTMOBGHBJG8XXGVZ6SARAMWC&amp;marketplace=FLIPKART&amp;q=realmegtneo3t&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=aabnij60v40000001722868749069&amp;qH=d41a393df17116b9" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="realme GT Neo 3T (Shade Black, 128 GB)" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/2/9/c/-original-imaghzfgbgyafbgq.jpeg?q=70"/></div></div></div><div class="qaR90o"><div class="A8uQAd"><span class="Lni97G"><label class="tJjCVx"><input class="vn9L2C" readonly="" ty
# ...

# %%
bigbox[0].div.div.div.a["href"]
# Out:
# '/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&lid=LSTMOBGHBJG8XXGVZ6SARAMWC&marketplace=FLIPKART&q=realmegtneo3t&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&ppt=None&ppn=None&ssid=aabnij60v40000001722868749069&qH=d41a393df17116b9'

# %%
bigbox
# Out:
# [<div class="cPHDOP col-12-12"><div class="_75nlfW"><div data-id="MOBGHBJG8XXGVZ6S" style="width:100%"><div class="tUxRFH"><a class="CGtC98" href="/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&amp;lid=LSTMOBGHBJG8XXGVZ6SARAMWC&amp;marketplace=FLIPKART&amp;q=realmegtneo3t&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=aabnij60v40000001722868749069&amp;qH=d41a393df17116b9" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="realme GT Neo 3T (Shade Black, 128 GB)" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/2/9/c/-original-imaghzfgbgyafbgq.jpeg?q=70"/></div></div></div><div class="qaR90o"><div class="A8uQAd"><span class="Lni97G"><label class="tJjCVx"><input class="vn9L2C" readonly="" t
# ...

# %%
go_to_particular_page_links = []

# %%
for i in bigbox:
    go_to_particular_page_links.append("https://www.flipkart.com" + i.div.div.div.a["href"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[182], line 2
#       1 for i in bigbox:
# ----> 2     go_to_particular_page_links.append("https://www.flipkart.com" + i.div.div.div.a["href"])
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
go_to_particular_page_links
# Out:
# ['https://www.flipkart.com/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&lid=LSTMOBGHBJG8XXGVZ6SARAMWC&marketplace=FLIPKART&q=realmegtneo3t&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&ppt=None&ppn=None&ssid=aabnij60v40000001722868749069&qH=d41a393df17116b9',
#  'https://www.flipkart.com/realme-gt-neo-3t-drifting-white-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJGT9GH23W9&lid=LSTMOBGHBJGT9GH23W9XTKSY9&marketplace=FLIPKART&q=realmegtneo3t&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJGT9GH23W9.SEARCH&ppt=None&ppn=None&ssid=aabnij60v40000001722868749069&qH=d41a393df17116b9',
# ...

# %%
mobile_1 = go_to_particular_page_links[0]

# %%
mobile_1
# Out:
# 'https://www.flipkart.com/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&lid=LSTMOBGHBJG8XXGVZ6SARAMWC&marketplace=FLIPKART&q=realmegtneo3t&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&ppt=None&ppn=None&ssid=aabnij60v40000001722868749069&qH=d41a393df17116b9'

# %%
mobile_response = requests.get(mobile_1)
mobile_response
# Out:
# <Response [200]>

# %%
mobile_1
# Out:
# 'https://www.flipkart.com/realme-gt-neo-3t-shade-black-128-gb/p/itmd1b8c6a6c8604?pid=MOBGHBJG8XXGVZ6S&lid=LSTMOBGHBJG8XXGVZ6SARAMWC&marketplace=FLIPKART&q=realmegtneo3t&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=54066818-a044-4469-9b73-5b5d20217c03.MOBGHBJG8XXGVZ6S.SEARCH&ppt=None&ppn=None&ssid=aabnij60v40000001722868749069&qH=d41a393df17116b9'

# %%
mobile_soup = BeautifulSoup(mobile_response.text,"html.parser")

# %%
mobile_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
reviews_list = mobile_soup.find_all("div",{"class":"col EPCmJX"})
reviews_list
# Out:
# [<div class="col EPCmJX"><div class="row"><div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div><p class="z9E0IG">Really Nice</p></div><div class="row"><div class="ZmyHeo"><div><div class="">Overall the device is good. <br>Back cam is decent but the front is ok in good light and poor in low light.<br>Battery charging is very fast but backup is not good. <br/>The phone is not handy, it feels a bit large in hand.<br/>The display and speakers are good. <br/>Performance, no need to mention.</br></br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div></div><div class="xmAgz5 pVVA7t"><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_68d988ba71c4478f890b3afc07fd46d4.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row gHqwa8"><div class="row"><p class="_2NsDsF AwS1CA">Naveen Rachakonda</p><svg class="VjlQyz" height="14" viewbox="0 0 12 12" width="14" xml
# ...

# %%
reviews_list[0]
# Out:
# <div class="col EPCmJX"><div class="row"><div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div><p class="z9E0IG">Really Nice</p></div><div class="row"><div class="ZmyHeo"><div><div class="">Overall the device is good. <br>Back cam is decent but the front is ok in good light and poor in low light.<br>Battery charging is very fast but backup is not good. <br/>The phone is not handy, it feels a bit large in hand.<br/>The display and speakers are good. <br/>Performance, no need to mention.</br></br></div><span class="wTYmpv"><span>READ MORE</span></span></div></div></div><div class="xmAgz5 pVVA7t"><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_68d988ba71c4478f890b3afc07fd46d4.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row gHqwa8"><div class="row"><p class="_2NsDsF AwS1CA">Naveen Rachakonda</p><svg class="VjlQyz" height="14" viewbox="0 0 12 12" width="14" xmln
# ...

# %%
reviews_list[0].find("div",{"class":"row gHqwa8"})
# Out:
# <div class="row gHqwa8"><div class="row"><p class="_2NsDsF AwS1CA">Naveen Rachakonda</p><svg class="VjlQyz" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="MztJPv" id="review-01cc60e0-4c13-4e9c-ab83-b646ec837d2e"><span>Certified Buyer</span><span>, Rangareddy</span></p><div></div><p class="_2NsDsF">Oct, 2022</p></div><div class="vMTK1V"><div class="row"><div class="qhmk-f"><div class="_6kK6mk"><svg class="U6FW-N" height="15" width="20" xmlns="http://www.w3.org/2000/svg"><path class="kX6HBt" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.
# ...

# %%
reviews_list[0].find("div",{"class":"row gHqwa8"}).div
# Out:
# <div class="row"><p class="_2NsDsF AwS1CA">Naveen Rachakonda</p><svg class="VjlQyz" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="MztJPv" id="review-01cc60e0-4c13-4e9c-ab83-b646ec837d2e"><span>Certified Buyer</span><span>, Rangareddy</span></p><div></div><p class="_2NsDsF">Oct, 2022</p></div>

# %%
reviews_list[0].find("div",{"class":"row gHqwa8"}).div.p
# Out:
# <p class="_2NsDsF AwS1CA">Naveen Rachakonda</p>

# %%
reviews_list[0].find("div",{"class":"row gHqwa8"}).div.p.text
# Out:
# 'Naveen Rachakonda'

# %%
reviewers_names_list = []

# %%
for i in reviews_list:
    reviewers_names_list.append(i.find("div",{"class":"row gHqwa8"}).div.p.text)

# %%
reviewers_names_list
# Out:
# ['Naveen Rachakonda',
#  'Anil Velpula',
#  'AKILAN Akilan ktm',
#  'Mananjay Mayank',
#  'Raj deep Pattanaik',
#  'Flipkart Customer',
#  'Samir Bala',
#  'Alok Mahankuda',
#  'Ravi Samant',
#  'Appu Chandran']

# %%
print(len(reviews_list))
len(reviewers_names_list)
# Out:
# 10
# 10

# %%
reviews_list[0].div.div.text
# Out:
# '4'

# %%
ratings_list = []

# %%
for i in reviews_list:
    ratings_list.append(i.div.div.text)

# %%
ratings_list
# Out:
# ['4', '5', '5', '5', '4', '5', '5', '5', '5', '5']

# %%
reviews_list[0].div.p.text
# Out:
# 'Really Nice'

# %%
comment_header = []

# %%
for i in reviews_list:
    comment_header.append(i.div.p.text)

# %%
comment_header
# Out:
# ['Really Nice',
#  'Super!',
#  'Worth every penny',
#  'Highly recommended',
#  'Pretty good',
#  'Classy product',
#  'Perfect product!',
#  'Terrific purchase',
#  'Worth every penny',
#  'Great product']

# %%
reviews_list[0].find("div",{"class":"ZmyHeo"}).div.div.text
# Out:
# 'Overall the device is good. Back cam is decent but the front is ok in good light and poor in low light.Battery charging is very fast but backup is not good. The phone is not handy, it feels a bit large in hand.The display and speakers are good. Performance, no need to mention.'

# %%
actual_comments_list = []

# %%
for i in reviews_list:
    actual_comments_list.append(i.find("div",{"class":"ZmyHeo"}).div.div.text)

# %%
actual_comments_list
# Out:
# ['Overall the device is good. Back cam is decent but the front is ok in good light and poor in low light.Battery charging is very fast but backup is not good. The phone is not handy, it feels a bit large in hand.The display and speakers are good. Performance, no need to mention.',
#  'Everything good i love it i purchase another one for my friend.....',
#  'Nice product camera 📸 picture quality is very good battery 🔋 life is ok quick charging and charging time is save I am using for 1 mounth very nice mobile',
#  'The all rounder phone...strongly recommend to all.',
#  'Yup some experiments are awesome.a alrounder set camera 10 /8,bettery are uper level most of the proform is 64 al nd gameing was so cool🔥',
#  'Super 💗',
#  'So good product i am happy ☺',
#  'Display is very goodValue for money 😊',
#  'Very good Phone by Realme in this price',
# ...

# %%
len(actual_comments_list)
# Out:
# 10
